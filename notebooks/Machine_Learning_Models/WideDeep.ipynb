# %% [markdown]
# - WideDeep: DeepLearning * Wide Linear Modelの組み合わせ
#
# - カテゴリカルデータと混合データセット(数値+カテゴリ)を扱う推薦システムや分類問題に適している．
#
# - 実装手順
# - Leave-One-Out分割
# - user_idとitem_idをLabel_Encodingする
# - Wide側をOne-Hot-Encodingして，Deep側をuserとitemをIDとしてEmbeddingする
# - モデル構築(Wide部分とDeep部分して，結合と出力する(Wide側とDeep出力をConcatenateして，出力層でsigmoidなどの活性化関数を用いる))
# - モデル学習(損失関数は，binary_crossentropy, 適当なbatch_sizeとepoch数で実行する)
# - 評価指標算出

# %%
pip install pytorch-widedeep
# Out:
# Collecting pytorch-widedeep
#   Downloading pytorch_widedeep-1.6.5-py3-none-any.whl (22.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.0/22.0 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting torchmetrics>=1.3.1
#   Downloading torchmetrics-1.7.2-py3-none-any.whl (962 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.5/962.5 kB 10.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting fastparquet>=2024.2.0
#   Downloading fastparquet-2024.11.0-cp310-cp310-macosx_11_0_arm64.whl (684 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.1/684.1 kB 10.6 MB/s eta 0:00:008.4 MB/s eta 0:00:01
# Collecting spacy
#   Downloading spacy-3.8.7-cp310-cp310-macosx_11_0_arm64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting transformers>=4.37.0
#   Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 9.3 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Requirement already satisfied: tqdm in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pytorch-widedeep) (4.67.1)
# Requirement already satisfied: torch>=2.0.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pytorch-widedeep) (2.7.1)
# Collecting torchvision>=0.15.0
#   Downloading torchvision-0.22.1-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.9 MB/s eta 0:00:0031m12.4 MB/s eta 0:00:01
# Collecting sentencepiece>=0.2.0
#   Downloading sentencepiece-0.2.0-cp310-cp310-macosx_11_0_arm64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.2 MB/s eta 0:00:008.0 MB/s eta 0:00:01
# Collecting gensim
#   Downloading gensim-4.3.3-cp310-cp310-macosx_11_0_arm64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 11.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pandas>=1.3.5 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pytorch-widedeep) (2.2.3)
# Collecting opencv-contrib-python>=4.9.0.80
#   Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (46.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 MB 9.6 MB/s eta 0:00:000m eta 0:00:010:00:01
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pytorch-widedeep) (1.6.1)
# Collecting wrapt
#   Downloading wrapt-1.17.2-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-20.0.0-cp310-cp310-macosx_12_0_arm64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 11.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting scipy<=1.12.0,>=1.7.3
#   Downloading scipy-1.12.0-cp310-cp310-macosx_12_0_arm64.whl (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 9.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Requirement already satisfied: numpy<2.0.0,>=1.21.6 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pytorch-widedeep) (1.26.4)
# Collecting sentence-transformers>=2.3.0
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 11.6 MB/s eta 0:00:00
# Collecting einops
#   Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from fastparquet>=2024.2.0->pytorch-widedeep) (2025.5.1)
# Collecting cramjam>=2.3
#   Downloading cramjam-2.10.0-cp310-cp310-macosx_11_0_arm64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.7 MB/s eta 0:00:007.8 MB/s eta 0:00:01m
# Requirement already satisfied: packaging in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from fastparquet>=2024.2.0->pytorch-widedeep) (25.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pandas>=1.3.5->pytorch-widedeep) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pandas>=1.3.5->pytorch-widedeep) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from pandas>=1.3.5->pytorch-widedeep) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from scikit-learn>=1.0.2->pytorch-widedeep) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from scikit-learn>=1.0.2->pytorch-widedeep) (3.6.0)
# Requirement already satisfied: Pillow in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from sentence-transformers>=2.3.0->pytorch-widedeep) (11.2.1)
# Collecting huggingface-hub>=0.20.0
#   Downloading huggingface_hub-0.32.4-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.1/512.1 kB 6.6 MB/s eta 0:00:006.8 MB/s eta 0:00:01
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from sentence-transformers>=2.3.0->pytorch-widedeep) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-widedeep) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-widedeep) (3.1.6)
# Requirement already satisfied: networkx in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-widedeep) (3.4.2)
# Requirement already satisfied: filelock in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-widedeep) (3.18.0)
# Collecting lightning-utilities>=0.8.0
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: requests in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from transformers>=4.37.0->pytorch-widedeep) (2.32.3)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from transformers>=4.37.0->pytorch-widedeep) (6.0.2)
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.6/284.6 kB 3.7 MB/s eta 0:00:004.0 MB/s eta 0:00:01
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 11.9 MB/s eta 0:00:0031m12.1 MB/s eta 0:00:01
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 12.6 MB/s eta 0:00:00
# Collecting smart-open>=1.8.1
#   Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.5 MB/s eta 0:00:00
# Collecting typer<1.0.0,>=0.3.0
#   Downloading typer-0.16.0-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 6.4 MB/s eta 0:00:00
# Collecting thinc<8.4.0,>=8.3.4
#   Downloading thinc-8.3.6-cp310-cp310-macosx_11_0_arm64.whl (844 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 844.9/844.9 kB 9.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.2/444.2 kB 8.7 MB/s eta 0:00:0031m11.1 MB/s eta 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.13-cp310-cp310-macosx_11_0_arm64.whl (26 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.11-cp310-cp310-macosx_11_0_arm64.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 7.0 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.10-cp310-cp310-macosx_11_0_arm64.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.3/127.3 kB 9.9 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 8.2 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.5.1-cp310-cp310-macosx_11_0_arm64.whl (634 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 634.4/634.4 kB 10.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: setuptools in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from spacy->pytorch-widedeep) (65.5.0)
# Collecting weasel<0.5.0,>=0.1.0
#   Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 5.1 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.1.2
#   Downloading hf_xet-1.1.3-cp37-abi3-macosx_11_0_arm64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 8.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting language-data>=1.2
#   Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 9.7 MB/s eta 0:00:0010.2 MB/s eta 0:00:01
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.0 MB/s eta 0:00:0031m10.8 MB/s eta 0:00:01
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pytorch-widedeep) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests->transformers>=4.37.0->pytorch-widedeep) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests->transformers>=4.37.0->pytorch-widedeep) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests->transformers>=4.37.0->pytorch-widedeep) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests->transformers>=4.37.0->pytorch-widedeep) (2.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.0->pytorch-widedeep) (1.3.0)
# Collecting thinc<8.4.0,>=8.3.4
#   Downloading thinc-8.3.4-cp310-cp310-macosx_11_0_arm64.whl (779 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.4/779.4 kB 10.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting blis<1.3.0,>=1.2.0
#   Downloading blis-1.2.1-cp310-cp310-macosx_11_0_arm64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting click>=8.0.0
#   Downloading click-8.2.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 8.1 MB/s eta 0:00:00
# Collecting rich>=10.11.0
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 9.1 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Downloading cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->pytorch-widedeep) (3.0.2)
# Collecting marisa-trie>=1.1.0
#   Downloading marisa_trie-1.2.1-cp310-cp310-macosx_11_0_arm64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.7/174.7 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->pytorch-widedeep) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 4.8 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: sentencepiece, cymem, wrapt, wasabi, typing-inspection, spacy-loggers, spacy-legacy, shellingham, scipy, safetensors, regex, pydantic-core, pyarrow, opencv-contrib-python, murmurhash, mdurl, marisa-trie, lightning-utilities, hf-xet, einops, cramjam, cloudpathlib, click, catalogue, blis, annotated-types, srsly, smart-open, pydantic, preshed, markdown-it-py, language-data, huggingface-hub, torchvision, torchmetrics, tokenizers, rich, langcodes, gensim, fastparquet, confection, typer, transformers, thinc, weasel, sentence-transformers, spacy, pytorch-widedeep
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# Successfully installed annotated-types-0.7.0 blis-1.2.1 catalogue-2.0.10 click-8.2.1 cloudpathlib-0.21.1 confection-0.1.5 cramjam-2.10.0 cymem-2.0.11 einops-0.8.1 fastparquet-2024.11.0 gensim-4.3.3 hf-xet-1.1.3 huggingface-hub-0.32.4 langcodes-3.5.0 language-data-1.3.0 lightning-utilities-0.14.3 marisa-trie-1.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.13 opencv-contrib-python-4.11.0.86 preshed-3.0.10 pyarrow-20.0.0 pydantic-2.11.5 pydantic-core-2.33.2 pytorch-widedeep-1.6.5 regex-2024.11.6 rich-14.0.0 safetensors-0.5.3 scipy-1.12.0 sentence-transformers-4.1.0 sentencepiece-0.2.0 shellingham-1.5.4 smart-open-7.1.0 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.4 tokenizers-0.21.1 torchmetrics-1.7.2 torchvision-0.22.1 transformers-4.52.4 typer-0.16.0 typing-inspection-0.4.1 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-macosx_12_0_arm64.whl (252.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 MB 10.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting ml-dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.1-cp310-cp310-macosx_10_9_universal2.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.5/671.5 kB 10.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting h5py>=3.11.0
#   Downloading h5py-3.14.0-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 18.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: setuptools in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from tensorflow) (65.5.0)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.4 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting keras>=3.5.0
#   Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting tensorboard~=2.19.0
#   Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 16.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from tensorflow) (4.13.2)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 21.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3
#   Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.1/418.1 kB 21.2 MB/s eta 0:00:00
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six>=1.12.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.73.0-cp310-cp310-macosx_11_0_universal2.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 23.5 MB/s eta 0:00:000:00:01 eta 0:00:01
# Requirement already satisfied: packaging in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from tensorflow) (25.0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.3.0-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 12.3 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 18.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Collecting optree
#   Downloading optree-0.16.0-cp310-cp310-macosx_11_0_arm64.whl (330 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.3/330.3 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: rich in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Collecting namex
#   Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 6.2 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/kurokawa/.pyenv/versions/3.10.13/envs/py310-surprise/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Installing collected packages: namex, libclang, flatbuffers, wheel, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, markdown, h5py, grpcio, google-pasta, gast, absl-py, tensorboard, astunparse, keras, tensorflow
# Successfully installed absl-py-2.3.0 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.73.0 h5py-3.14.0 keras-3.10.0 libclang-18.1.1 markdown-3.8 ml-dtypes-0.5.1 namex-0.1.0 opt-einsum-3.4.0 optree-0.16.0 protobuf-5.29.5 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-3.1.0 werkzeug-3.1.3 wheel-0.45.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.3.0
# annotated-types              0.7.0
# anyio                        4.9.0
# appnope                      0.1.4
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# async-lru                    2.0.5
# attrs                        25.3.0
# babel                        2.17.0
# beautifulsoup4               4.13.4
# bleach                       6.2.0
# blis                         1.2.1
# catalogue                    2.0.10
# certifi                      2025.4.26
# cffi                         1.17.1
# charset-normalizer           3.4.2
# click                        8.2.1
# cloudpathlib                 0.21.1
# comm                         0.2.2
# confection                   0.1.5
# contourpy                    1.3.2
# cramjam                      2.10.0
# cycler                       0.12.1
# cymem                        2.0.11
# debugpy                      1.8.14
# decorator                    5.2.1
# defusedxml                   0.7.1
# einops                       0.8.1
# exceptiongroup               1.3.0
# executing                    2.2.0
# fastjsonschema               2.21.1
# fastparquet                  2024.11.0
# filelock                     3.18.0
# flatbuffers                  25.2.10
# fonttools                    4.58.0
# fqdn                         1.5.1
# fsspec                       2025.5.1
# gast                         0.6.0
# gensim                       4.3.3
# google-pasta                 0.2.0
# grpcio                       1.73.0
# h11                          0.16.0
# h5py                         3.14.0
# hf-xet                       1.1.3
# httpcore                     1.0.9
# httpx                        0.28.1
# huggingface-hub              0.32.4
# idna                         3.10
# ipykernel                    6.29.5
# ipython                      8.36.0
# isoduration                  20.11.0
# jedi                         0.19.2
# Jinja2                       3.1.6
# joblib                       1.5.0
# json5                        0.12.0
# jsonpointer                  3.0.0
# jsonschema                   4.23.0
# jsonschema-specifications    2025.4.1
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# jupyter-events               0.12.0
# jupyter-lsp                  2.2.5
# jupyter_server               2.16.0
# jupyter_server_terminals     0.5.3
# jupyterlab                   4.4.2
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.27.3
# keras                        3.10.0
# kiwisolver                   1.4.8
# langcodes                    3.5.0
# language_data                1.3.0
# libclang                     18.1.1
# lightning-utilities          0.14.3
# llvmlite                     0.44.0
# marisa-trie                  1.2.1
# Markdown                     3.8
# markdown-it-py               3.0.0
# MarkupSafe                   3.0.2
# matplotlib                   3.10.3
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# mistune                      3.1.3
# ml_dtypes                    0.5.1
# mpmath                       1.3.0
# murmurhash                   1.0.13
# namex                        0.1.0
# narwhals                     1.41.1
# nbclient                     0.10.2
# nbconvert                    7.16.6
# nbformat                     5.10.4
# nest-asyncio                 1.6.0
# networkx                     3.4.2
# notebook                     7.4.2
# notebook_shim                0.2.4
# numba                        0.61.2
# numpy                        1.26.4
# opencv-contrib-python        4.11.0.86
# opt_einsum                   3.4.0
# optree                       0.16.0
# overrides                    7.7.0
# packaging                    25.0
# pandas                       2.2.3
# pandocfilters                1.5.1
# parso                        0.8.4
# pexpect                      4.9.0
# pillow                       11.2.1
# pip                          23.0.1
# platformdirs                 4.3.8
# plotly                       6.1.2
# polars                       1.30.0
# preshed                      3.0.10
# prometheus_client            0.22.0
# prompt_toolkit               3.0.51
# protobuf                     5.29.5
# psutil                       7.0.0
# ptyprocess                   0.7.0
# pure_eval                    0.2.3
# pyarrow                      20.0.0
# pycparser                    2.22
# pydantic                     2.11.5
# pydantic_core                2.33.2
# Pygments                     2.19.1
# pynndescent                  0.5.13
# pyparsing                    3.2.3
# python-dateutil              2.9.0.post0
# python-json-logger           3.3.0
# pytorch-widedeep             1.6.5
# pytz                         2025.2
# PyYAML                       6.0.2
# pyzmq                        26.4.0
# referencing                  0.36.2
# regex                        2024.11.6
# requests                     2.32.3
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rich                         14.0.0
# rpds-py                      0.25.1
# safetensors                  0.5.3
# scikit-learn                 1.6.1
# scikit-surprise              1.1.4
# scipy                        1.12.0
# seaborn                      0.13.2
# Send2Trash                   1.8.3
# sentence-transformers        4.1.0
# sentencepiece                0.2.0
# setuptools                   65.5.0
# shellingham                  1.5.4
# six                          1.17.0
# smart-open                   7.1.0
# sniffio                      1.3.1
# soupsieve                    2.7
# spacy                        3.8.7
# spacy-legacy                 3.0.12
# spacy-loggers                1.0.5
# srsly                        2.5.1
# stack-data                   0.6.3
# sympy                        1.14.0
# tensorboard                  2.19.0
# tensorboard-data-server      0.7.2
# tensorflow                   2.19.0
# tensorflow-io-gcs-filesystem 0.37.1
# termcolor                    3.1.0
# terminado                    0.18.1
# thinc                        8.3.4
# threadpoolctl                3.6.0
# tinycss2                     1.4.0
# tokenizers                   0.21.1
# tomli                        2.2.1
# torch                        2.7.1
# torchmetrics                 1.7.2
# torchvision                  0.22.1
# tornado                      6.5
# tqdm                         4.67.1
# traitlets                    5.14.3
# transformers                 4.52.4
# typer                        0.16.0
# types-python-dateutil        2.9.0.20250516
# typing_extensions            4.13.2
# typing-inspection            0.4.1
# tzdata                       2025.2
# umap-learn                   0.5.7
# uri-template                 1.3.0
# urllib3                      2.4.0
# wasabi                       1.1.3
# wcwidth                      0.2.13
# weasel                       0.4.1
# webcolors                    24.11.1
# webencodings                 0.5.1
# websocket-client             1.8.0
# Werkzeug                     3.1.3
# wheel                        0.45.1
# wrapt                        1.17.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Embedding, Flatten, Concatenate
from tensorflow.keras.models import Model

import warnings
warnings.filterwarnings('ignore')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # 0:all, 1:filter INFO, 2:filter WARNING, 3:only ERROR

# データ読み込み
cols = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=cols)
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Leave-One-Out分割
df['rank'] = df.groupby('user_id')['timestamp'].rank(method='first', ascending=False)
train_df = df[df['rank'] > 1].copy()
test_df = df[df['rank'] == 1].copy()

# ラベルエンコード
user_enc = LabelEncoder()
item_enc = LabelEncoder()
train_df['user'] = user_enc.fit_transform(train_df['user_id'])
train_df['item'] = item_enc.fit_transform(train_df['item_id'])
test_df = test_df[test_df['user_id'].isin(user_enc.classes_)]
test_df = test_df[test_df['item_id'].isin(item_enc.classes_)]
test_df['user'] = user_enc.transform(test_df['user_id'])
test_df['item'] = item_enc.transform(test_df['item_id'])

num_users = train_df['user'].nunique()
num_items = train_df['item'].nunique()

print("ok")
# Out:
# ok

# %%
# Wide側のOne-Hot-Encoding

# Train用
enc = OneHotEncoder()
X_wide_train = enc.fit_transform(train_df[['user', 'item']]).toarray()

# Test用
X_wide_test = enc.transform(test_df[['user', 'item']]).toarray()

# %%
# Deep側は埋め込み + MLP

# 入力層
user_input = Input(shape=(1,), name='user_input')
item_input = Input(shape=(1,), name='item_input')

# 埋め込み層
user_embed = Embedding(input_dim=num_users, output_dim=8)(user_input)
item_embed = Embedding(input_dim=num_items, output_dim=8)(item_input)

# Flatten
user_vec = Flatten()(user_embed)
item_vec = Flatten()(item_embed)

# 結合 & MLP
deep_concat = Concatenate()([user_vec, item_vec])
deep_out = Dense(32, activation='relu')(deep_concat)
deep_out = Dense(16, activation='relu')(deep_out)

# %%
# Deep側入力データ
X_user_train = train_df['user'].values
X_item_train = train_df['item'].values
X_user_test = test_df['user'].values
X_item_test = test_df['item'].values

y_train = (train_df['rating'] >= 4).astype(int).values  # 二値分類
y_test = (test_df['rating'] >= 4).astype(int).values

# %%
# モデル構築

# 入力層
wide_input = Input(shape=(X_wide_train.shape[1],), name='wide_input')
user_input = Input(shape=(1,), name='user_input')
item_input = Input(shape=(1,), name='item_input')

# 埋め込み層
user_embed = Embedding(input_dim=num_users, output_dim=8)(user_input)
item_embed = Embedding(input_dim=num_items, output_dim=8)(item_input)
user_vec = Flatten()(user_embed)
item_vec = Flatten()(item_embed)

# Deep部分（MLP）
deep_concat = Concatenate()([user_vec, item_vec])
deep_out = Dense(32, activation='relu')(deep_concat)
deep_out = Dense(16, activation='relu')(deep_out)

# Wide + Deep 結合 & 出力
combined = Concatenate()([wide_input, deep_out])
output = Dense(1, activation='sigmoid')(combined)

model = Model(inputs=[wide_input, user_input, item_input], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# モデル学習
model.fit([X_wide_train, X_user_train, X_item_train], y_train,
          epochs=5, batch_size=128, validation_split=0.1)
# Out:
# Epoch 1/5
# 697/697 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6120 - loss: 0.6429 - val_accuracy: 0.7020 - val_loss: 0.5711
# Epoch 2/5
# 697/697 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.7239 - loss: 0.5511 - val_accuracy: 0.7094 - val_loss: 0.5636
# Epoch 3/5
# 697/697 ━━━━━━━━━━━━━━━━━━━━ 1s 824us/step - accuracy: 0.7264 - loss: 0.5436 - val_accuracy: 0.7127 - val_loss: 0.5598
# Epoch 4/5
# 697/697 ━━━━━━━━━━━━━━━━━━━━ 1s 846us/step - accuracy: 0.7282 - loss: 0.5358 - val_accuracy: 0.7107 - val_loss: 0.5578
# Epoch 5/5
# 697/697 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step - accuracy: 0.7342 - loss: 0.5243 - val_accuracy: 0.7111 - val_loss: 0.5544

# %%
from collections import defaultdict

n_negative = 99
all_items = set(train_df['item'].unique())

user_item_score = defaultdict(list)

for user in test_df['user'].unique():
    # 正解アイテム1件取得（安全な取得方法）
    gt_item = test_df[test_df['user'] == user].iloc[0]['item']

    # 負例アイテムのサンプリング
    negatives = list(all_items - {gt_item})
    sampled_negatives = np.random.choice(negatives, size=n_negative, replace=False)

    # 評価対象アイテム集合（正解含む）
    items_to_score = np.append(sampled_negatives, gt_item)

    # 入力データ作成
    wide_feat = enc.transform([[user, item] for item in items_to_score]).toarray()
    user_input_batch = np.full(len(items_to_score), user)
    item_input_batch = items_to_score

    # 推薦スコア予測
    scores = model.predict([wide_feat, user_input_batch, item_input_batch], verbose=0).flatten()

    # スコア保存
    user_item_score[user] = list(zip(items_to_score, scores))

# 推薦リスト作成（Top-10）
recommendations = {
    user: [item for item, _ in sorted(items, key=lambda x: x[1], reverse=True)[:10]]
    for user, items in user_item_score.items()
}

# Ground truth 作成
ground_truth = {
    user: [test_df[test_df['user'] == user].iloc[0]['item']]
    for user in user_item_score
}

# %%
# 評価

from Evaluation_index import recall_at_k, precision_at_k, ndcg_at_k, mrr_at_k, hit_at_k

print("=== WideDeep モデル評価結果（Top-10）===")
print(f"Recall@10    : {recall_at_k(recommendations, ground_truth, 10):.4f}")
print(f"Precision@10 : {precision_at_k(recommendations, ground_truth, 10):.4f}")
print(f"NDCG@10      : {ndcg_at_k(recommendations, ground_truth, 10):.4f}")
print(f"MRR@10       : {mrr_at_k(recommendations, ground_truth, 10):.4f}")
print(f"Hit@10       : {hit_at_k(recommendations, ground_truth, 10):.4f}")

print("\n=== RecBole モデル評価結果（Top-10）===")
print(f"Recall@10    : 0.0534")
print(f"Precision@10 : 0.0620")
print(f"NDCG@10      : 0.0774")
print(f"MRR@10       : 0.1564")
print(f"Hit@10       : 0.3560")
# Out:
# === WideDeep モデル評価結果（Top-10）===
# Recall@10    : 0.1413
# Precision@10 : 0.0141
# NDCG@10      : 0.0706
# MRR@10       : 0.0492
# Hit@10       : 0.1413
#
# === RecBole モデル評価結果（Top-10）===
# Recall@10    : 0.0534
# Precision@10 : 0.0620
# NDCG@10      : 0.0774
# MRR@10       : 0.1564
# Hit@10       : 0.3560
